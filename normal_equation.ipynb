# %% [markdown]
# <a href="https://colab.research.google.com/github/Poseidon4006/coding_ninja_ML101/blob/main/normal_equation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn

# %% [markdown]
# ### Normal equation

# %%
import numpy as np 

np.random.seed(42)
m = 100 # number of training examples
X = 2 * np.random.rand(m,1) # column vector( uniform distribution)
y = 5 + 3 * X + np.random.randn(m, 1) # column vector (standard normal distribution)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.plot(X, y,"b.")
plt.xlabel("$x_1$")
plt.ylabel("$y$",rotation=0)
plt.axis([0,2,0,15])
plt.grid()
plt.show()

# %%
from sklearn.preprocessing import add_dummy_feature
X_b = np.c_[np.ones((m,1)), X] # adding dummy features 
#X_b = add_dummy_feature(X)
theta_best = np.linalg.inv(X_b.T @ X_b) @ X_b.T @ y

# %%
theta_best
# Out:
# array([[5.21509616],
#        [2.77011339]])

# %%
X_new = np.array([[0],[2]])
X_new_b = add_dummy_feature(X_new)
y_predict = X_new_b @ theta_best
y_predict
# Out:
# array([[ 5.21509616],
#        [10.75532293]])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))  # extra code – not needed, just formatting
plt.plot(X_new, y_predict, "r-")
plt.plot(X, y, "b.")

# extra code – beautifies and saves Figure 4–2
plt.xlabel("$x_1$")
plt.ylabel("$y$", rotation=0)
plt.axis([0, 2, 0, 15])
plt.grid()
plt.legend(loc="upper left")

plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
